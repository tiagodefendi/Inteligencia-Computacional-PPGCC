# %% [markdown]
# # Momentos de HU - Base Four Shape
#
#
# ## Objetivo Geral:
# Utilizando os códigos Matlab/Octave juntamente com a base de formas, mostre a acurácia para a tarefa. Utilize 60% para treinamento e 40% para teste. Selecione as 600 primeiras imagens para treino e a restante para teste.
#
#
# ## Objetivos Específicos:
#
# 1. Utilizando os códigos de Momentos Invariantes de HU ([código de exemplo](https://drive.matlab.com/sharing/03e51873-545c-4e56-8e5e-e52deb71bf79)). Existe outros códigos em Python, C, e outros
# 2. Utilize a base four shapes ([Base de Dados](https://www.dropbox.com/scl/fi/j23s8ck7brc1107b6jx3w/fourShapes_2.tar.gz?rlkey=hkvy84zqqukgmf833ae9i4x6a&dl=0));
# 3. Utilize o k-NN como classificador (neste momento só vamos usar o Classificador k-NN) - Pode usar pronto do Matlab ou do Scikit-learn.
# 4. Avalie com diferentes parâmetros (número de zonas horizontais e verticais) para os momentos invariantes de HU e apresente o melhor resultado.

# %%
# !mkdir treino
# Out:
# mkdir: cannot create directory ‘treino’: File exists

# %%
# !tar -xzf ./fourShapes.tar.gz -C ./treino/

# %%
# !tar -xzf ./fourShapes_2.tar.gz -C ./treino/

# %%
# !unzip ./formas_out_teste
# Out:
# Archive:  ./formas_out_teste.zip
# replace formas_out/3_star/10_aug_1.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace formas_out/3_star/1002_aug_1.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# !unzip ./train_set.zip
# Out:
# Archive:  ./train_set.zip
#    creating: train_set/
#   inflating: train_set/.MATLABDriveTag
#    creating: train_set/0/
#   inflating: train_set/0/.MATLABDriveTag
#   inflating: train_set/0/116150-6-3.bmp
#   inflating: train_set/0/116151-10-3.bmp
#   inflating: train_set/0/116151-10-4.bmp
#   inflating: train_set/0/116151-10-5.bmp
#   inflating: train_set/0/116151-13-3.bmp
#   inflating: train_set/0/116151-15-5.bmp
#   inflating: train_set/0/116151-17-4.bmp
#   inflating: train_set/0/116151-9-6.bmp
#   inflating: train_set/0/116152-19-4.bmp
#   inflating: train_set/0/116153-28-6.bmp
#   inflating: train_set/0/116154-3-6.bmp
#   inflating: train_set/0/116154-7-6.bmp
#   inflating: train_set/0/116154-9-4.bmp
#   inflating: train_set/0/116155-11-3.bmp
#   inflating: train_set/0/116156-1-4.bmp
#   inflating: train_set/0/116156-3-3.bmp
#   inflating: train_set/0/116158-4-5.bmp
#   inflating: train_set/0/116173-4-3.bmp
#   inflating: train_set/0/116174-6-3.bmp
#   inflating: train_set/0/116174-6-4.bmp
#   inflating: train_set/0/116174-6-5.bmp
#   inflating: train_set/0/116174-9-3.bmp
#   inflating: train_set/0/116176-13-6.bmp
#   inflating: train_set/0/116176-14-3.bmp
#   inflating: train_set/0/116176-14-6.bmp
#   inflating: train_set/0/116176-16-6.bmp
#   inflating: train_set/0/116177-19-3.bmp
#   inflating: train_set/0/126115-1-4.bmp
#   inflating: train_set/0/126115-2-3.bmp
#   inflating: train_set/0/126116-4-4.bmp
#   inflating: train_set/0/126116-5-4.bmp
#   inflating: train_set/0/126116-8-3.bmp
#   inflating: train_set/0/126116-8-4.bmp
#   inflating: train_set/0/126117-11-4.bmp
#   inflating: train_set/0/126117-13-6.bmp
#   inflating: train_set/0/126117-15-3.bmp
#   inflating: train_set/0/126118-20-4.bmp
#   inflating: train_set/0/126118-20-5.bmp
#   inflating: train_set/0/126118-21-3.bmp
#   inflating: train_set/0/126118-23-4.bmp
#   inflating: train_set/0/126119-27-3.bmp
#   inflating: train_set/0/126119-28-6.bmp
#   inflating: train_set/0/126125-18-6.bmp
#   inflating: train_set/0/126125-19-3.bmp
#   inflating: train_set/0/126140-6-4.bmp
#   inflating: train_set/0/126140-8-6.bmp
#   inflating: train_set/0/126142-4-6.bmp
#   inflating: train_set/0/126147-10-3.bmp
#   inflating: train_set/0/126147-6-3.bmp
#   inflating: train_set/0/126147-6-4.bmp
#   inflating: train_set/0/126151-8-3.bmp
#   inflating: train_set/0/126151-9-4.bmp
#   inflating: train_set/0/126152-19-4.bmp
#   inflating: train_set/0/126152-19-5.bmp
#   inflating: train_set/0/126152-20-6.bmp
#   inflating: train_set/0/126152-21-3.bmp
#   inflating: train_set/0/126153-1-3.bmp
#   inflating: train_set/0/126153-1-4.bmp
#   inflating: train_set/0/126153-24-4.bmp
#   inflating: train_set/0/126153-25-6.bmp
#   inflating: train_set/0/126153-28-6.bmp
#   inflating: train_set/0/126153-29-3.bmp
#   inflating: train_set/0/126153-29-4.bmp
#   inflating: train_set/0/126153-3-5.bmp
#   inflating: train_set/0/126154-10-5.bmp
#   inflating: train_set/0/126154-10-6.bmp
#   inflating: train_set/0/126154-15-5.bmp
#   inflating: train_set/0/126154-5-3.bmp
#   inflating: train_set/0/126154-5-6.bmp
#   inflating: train_set/0/126154-9-3.bmp
#   inflating: train_set/0/136150-1-6.bmp
#   inflating: train_set/0/136150-28-3.bmp
#   inflating: train_set/0/136150-3-5.bmp
#   inflating: train_set/0/136150-32-6.bmp
#   inflating: train_set/0/136151-15-6.bmp
#   inflating: train_set/0/136151-7-5.bmp
#   inflating: train_set/0/136151-9-3.bmp
#   inflating: train_set/0/136152-21-4.bmp
#   inflating: train_set/0/37138-2-4.bmp
#   inflating: train_set/0/37138-3-5.bmp
#   inflating: train_set/0/37138-4-5.bmp
#   inflating: train_set/0/37138-6-6.bmp
#   inflating: train_set/0/37139-1-3.bmp
#   inflating: train_set/0/37141-1-3.bmp
#   inflating: train_set/0/37141-2-4.bmp
#   inflating: train_set/0/37141-2-6.bmp
#   inflating: train_set/0/37141-3-3.bmp
#   inflating: train_set/0/37141-3-5.bmp
#   inflating: train_set/0/37142-2-3.bmp
#   inflating: train_set/0/37142-2-6.bmp
#   inflating: train_set/0/37144-13-5.bmp
#   inflating: train_set/0/37144-16-6.bmp
#   inflating: train_set/0/37144-18-4.bmp
#   inflating: train_set/0/37144-18-6.bmp
#   inflating: train_set/0/37145-19-5.bmp
#   inflating: train_set/0/37145-25-4.bmp
#   inflating: train_set/0/37145-25-6.bmp
#   inflating: train_set/0/37147-3-6.bmp
#   inflating: train_set/0/37150-24-3.bmp
#   inflating: train_set/0/37150-24-4.bmp
#    creating: train_set/1/
#   inflating: train_set/1/.MATLABDriveTag
#   inflating: train_set/1/116150-6-5.bmp
#   inflating: train_set/1/116150-6-6.bmp
#   inflating: train_set/1/116150-7-6.bmp
#   inflating: train_set/1/116151-11-6.bmp
#   inflating: train_set/1/116151-14-5.bmp
#   inflating: train_set/1/116151-17-5.bmp
#   inflating: train_set/1/116152-21-5.bmp
#   inflating: train_set/1/116153-28-3.bmp
#   inflating: train_set/1/116153-31-3.bmp
#   inflating: train_set/1/116154-3-3.bmp
#   inflating: train_set/1/116154-6-3.bmp
#   inflating: train_set/1/116158-5-4.bmp
#   inflating: train_set/1/116158-6-4.bmp
#   inflating: train_set/1/116170-11-6.bmp
#   inflating: train_set/1/116170-12-6.bmp
#   inflating: train_set/1/116170-16-3.bmp
#   inflating: train_set/1/116170-17-5.bmp
#   inflating: train_set/1/116170-19-3.bmp
#   inflating: train_set/1/116170-19-5.bmp
#   inflating: train_set/1/116171-28-6.bmp
#   inflating: train_set/1/116172-2-6.bmp
#   inflating: train_set/1/116174-6-6.bmp
#   inflating: train_set/1/116174-7-3.bmp
#   inflating: train_set/1/116174-8-3.bmp
#   inflating: train_set/1/116176-10-3.bmp
#   inflating: train_set/1/116176-12-4.bmp
#   inflating: train_set/1/116176-13-4.bmp
#   inflating: train_set/1/116176-14-5.bmp
#   inflating: train_set/1/116176-6-6.bmp
#   inflating: train_set/1/116176-8-3.bmp
#   inflating: train_set/1/126115-3-4.bmp
#   inflating: train_set/1/126117-13-3.bmp
#   inflating: train_set/1/126117-13-4.bmp
#   inflating: train_set/1/126117-16-4.bmp
#   inflating: train_set/1/126117-16-6.bmp
#   inflating: train_set/1/126117-17-4.bmp
#   inflating: train_set/1/126117-18-6.bmp
#   inflating: train_set/1/126118-20-6.bmp
#   inflating: train_set/1/126119-25-3.bmp
#   inflating: train_set/1/126125-19-4.bmp
#   inflating: train_set/1/126125-19-6.bmp
#   inflating: train_set/1/126151-10-5.bmp
#   inflating: train_set/1/126151-7-4.bmp
#   inflating: train_set/1/126151-9-6.bmp
#   inflating: train_set/1/126152-16-3.bmp
#   inflating: train_set/1/126152-16-5.bmp
#   inflating: train_set/1/126152-21-5.bmp
#   inflating: train_set/1/126152-22-5.bmp
#   inflating: train_set/1/126153-1-5.bmp
#   inflating: train_set/1/126153-26-3.bmp
#   inflating: train_set/1/126153-29-5.bmp
#   inflating: train_set/1/126154-12-3.bmp
#   inflating: train_set/1/126154-6-3.bmp
#   inflating: train_set/1/126154-6-4.bmp
#   inflating: train_set/1/136150-1-5.bmp
#   inflating: train_set/1/136150-32-5.bmp
#   inflating: train_set/1/136151-12-5.bmp
#   inflating: train_set/1/136151-16-6.bmp
#   inflating: train_set/1/136151-17-3.bmp
#   inflating: train_set/1/136151-17-5.bmp
#   inflating: train_set/1/136151-19-3.bmp
#   inflating: train_set/1/136151-19-5.bmp
#   inflating: train_set/1/136151-19-6.bmp
#   inflating: train_set/1/136151-7-3.bmp
#   inflating: train_set/1/136153-22-4.bmp
#   inflating: train_set/1/136153-23-4.bmp
#   inflating: train_set/1/136153-26-6.bmp
#   inflating: train_set/1/136153-27-4.bmp
#   inflating: train_set/1/136153-27-6.bmp
#   inflating: train_set/1/136153-29-3.bmp
#   inflating: train_set/1/136153-30-5.bmp
#   inflating: train_set/1/136156-13-4.bmp
#   inflating: train_set/1/136156-4-4.bmp
#   inflating: train_set/1/136156-4-5.bmp
#   inflating: train_set/1/136156-8-4.bmp
#   inflating: train_set/1/136157-15-5.bmp
#   inflating: train_set/1/136157-16-4.bmp
#   inflating: train_set/1/136157-21-3.bmp
#   inflating: train_set/1/136158-25-6.bmp
#   inflating: train_set/1/136158-5-5.bmp
#   inflating: train_set/1/136158-6-5.bmp
#   inflating: train_set/1/136159-8-6.bmp
#   inflating: train_set/1/136161-1-5.bmp
#   inflating: train_set/1/37138-3-6.bmp
#   inflating: train_set/1/37138-5-3.bmp
#   inflating: train_set/1/37138-6-4.bmp
#   inflating: train_set/1/37142-1-4.bmp
#   inflating: train_set/1/37142-1-6.bmp
#   inflating: train_set/1/37142-2-5.bmp
#   inflating: train_set/1/37142-3-3.bmp
#   inflating: train_set/1/37143-10-4.bmp
#   inflating: train_set/1/37143-7-6.bmp
#   inflating: train_set/1/37143-9-3.bmp
#   inflating: train_set/1/37144-13-6.bmp
#   inflating: train_set/1/37144-15-6.bmp
#   inflating: train_set/1/37145-23-3.bmp
#   inflating: train_set/1/37145-26-3.bmp
#   inflating: train_set/1/37145-26-5.bmp
#   inflating: train_set/1/37147-3-5.bmp
#   inflating: train_set/1/37148-4-5.bmp
#    creating: train_set/2/
#   inflating: train_set/2/.MATLABDriveTag
#   inflating: train_set/2/000.bmp
#   inflating: train_set/2/116151-14-3.bmp
#   inflating: train_set/2/116151-15-6.bmp
#   inflating: train_set/2/116152-20-5.bmp
#   inflating: train_set/2/116152-21-6.bmp
#   inflating: train_set/2/116153-26-3.bmp
#   inflating: train_set/2/116153-26-5.bmp
#   inflating: train_set/2/116153-28-4.bmp
#   inflating: train_set/2/116153-31-6.bmp
#   inflating: train_set/2/116154-3-4.bmp
#   inflating: train_set/2/116154-6-6.bmp
#   inflating: train_set/2/116170-14-6.bmp
#   inflating: train_set/2/116170-16-6.bmp
#   inflating: train_set/2/116170-17-6.bmp
#   inflating: train_set/2/116170-18-3.bmp
#   inflating: train_set/2/116171-23-3.bmp
#   inflating: train_set/2/116171-24-3.bmp
#   inflating: train_set/2/116171-27-4.bmp
#   inflating: train_set/2/116173-3-6.bmp
#   inflating: train_set/2/116174-9-4.bmp
#   inflating: train_set/2/116174-9-6.bmp
#   inflating: train_set/2/116175-2-5.bmp
#   inflating: train_set/2/116176-12-3.bmp
#   inflating: train_set/2/116176-15-6.bmp
#   inflating: train_set/2/116176-16-3.bmp
#   inflating: train_set/2/116176-8-4.bmp
#   inflating: train_set/2/126115-1-2.bmp
#   inflating: train_set/2/126116-4-6.bmp
#   inflating: train_set/2/126116-7-4.bmp
#   inflating: train_set/2/126116-8-6.bmp
#   inflating: train_set/2/126117-18-4.bmp
#   inflating: train_set/2/126118-22-5.bmp
#   inflating: train_set/2/126119-25-5.bmp
#   inflating: train_set/2/126119-26-6.bmp
#   inflating: train_set/2/126140-6-3.bmp
#   inflating: train_set/2/126140-6-6.bmp
#   inflating: train_set/2/126140-9-6.bmp
#   inflating: train_set/2/126143-5-4.bmp
#   inflating: train_set/2/126147-10-5.bmp
#   inflating: train_set/2/126151-7-5.bmp
#   inflating: train_set/2/126151-9-5.bmp
#   inflating: train_set/2/126152-15-4.bmp
#   inflating: train_set/2/126152-17-4.bmp
#   inflating: train_set/2/126152-20-5.bmp
#   inflating: train_set/2/126152-23-4.bmp
#   inflating: train_set/2/126153-25-3.bmp
#   inflating: train_set/2/126153-3-3.bmp
#   inflating: train_set/2/126154-15-4.bmp
#   inflating: train_set/2/136150-1-4.bmp
#   inflating: train_set/2/136150-28-5.bmp
#   inflating: train_set/2/136150-32-4.bmp
#   inflating: train_set/2/136151-12-6.bmp
#   inflating: train_set/2/136151-13-4.bmp
#   inflating: train_set/2/136151-15-4.bmp
#   inflating: train_set/2/136151-18-4.bmp
#   inflating: train_set/2/136151-8-3.bmp
#   inflating: train_set/2/136152-21-3.bmp
#   inflating: train_set/2/136153-23-6.bmp
#   inflating: train_set/2/136154-2-3.bmp
#   inflating: train_set/2/136156-10-3.bmp
#   inflating: train_set/2/136156-6-3.bmp
#   inflating: train_set/2/136156-8-3.bmp
#   inflating: train_set/2/136157-15-6.bmp
#   inflating: train_set/2/136157-19-6.bmp
#   inflating: train_set/2/136157-22-6.bmp
#   inflating: train_set/2/136158-25-3.bmp
#   inflating: train_set/2/136158-5-6.bmp
#   inflating: train_set/2/136159-7-3.bmp
#   inflating: train_set/2/136159-8-3.bmp
#   inflating: train_set/2/136159-9-3.bmp
#   inflating: train_set/2/136161-1-4.bmp
#   inflating: train_set/2/136163-5-6.bmp
#   inflating: train_set/2/136167-15-4.bmp
#   inflating: train_set/2/136167-17-4.bmp
#   inflating: train_set/2/136167-18-5.bmp
#   inflating: train_set/2/136167-18-6.bmp
#   inflating: train_set/2/136167-19-4.bmp
#   inflating: train_set/2/146150-10-5.bmp
#   inflating: train_set/2/146150-12-3.bmp
#   inflating: train_set/2/146150-15-3.bmp
#   inflating: train_set/2/146150-15-4.bmp
#   inflating: train_set/2/146150-7-4.bmp
#   inflating: train_set/2/146150-9-3.bmp
#   inflating: train_set/2/146150-9-6.bmp
#   inflating: train_set/2/146151-19-3.bmp
#   inflating: train_set/2/146151-20-3.bmp
#   inflating: train_set/2/37138-1-6.bmp
#   inflating: train_set/2/37142-1-5.bmp
#   inflating: train_set/2/37143-5-4.bmp
#   inflating: train_set/2/37143-9-5.bmp
#   inflating: train_set/2/37144-12-5.bmp
#   inflating: train_set/2/37144-13-4.bmp
#   inflating: train_set/2/37144-17-6.bmp
#   inflating: train_set/2/37145-22-5.bmp
#   inflating: train_set/2/37148-5-6.bmp
#   inflating: train_set/2/37148-6-3.bmp
#   inflating: train_set/2/37148-6-5.bmp
#   inflating: train_set/2/37150-24-5.bmp
#   inflating: train_set/2/37150-24-6.bmp
#   inflating: train_set/2/37151-2-6.bmp
#    creating: train_set/3/
#   inflating: train_set/3/.MATLABDriveTag
#   inflating: train_set/3/116151-15-4.bmp
#   inflating: train_set/3/116152-20-4.bmp
#   inflating: train_set/3/116152-23-4.bmp
#   inflating: train_set/3/116153-31-5.bmp
#   inflating: train_set/3/116154-6-5.bmp
#   inflating: train_set/3/116154-9-6.bmp
#   inflating: train_set/3/116155-11-4.bmp
#   inflating: train_set/3/116155-11-6.bmp
#   inflating: train_set/3/116156-1-6.bmp
#   inflating: train_set/3/116156-3-4.bmp
#   inflating: train_set/3/116156-3-6.bmp
#   inflating: train_set/3/116158-5-3.bmp
#   inflating: train_set/3/116158-6-5.bmp
#   inflating: train_set/3/116170-11-4.bmp
#   inflating: train_set/3/116171-27-5.bmp
#   inflating: train_set/3/116173-3-4.bmp
#   inflating: train_set/3/116173-4-6.bmp
#   inflating: train_set/3/116174-7-6.bmp
#   inflating: train_set/3/116175-2-3.bmp
#   inflating: train_set/3/116175-4-4.bmp
#   inflating: train_set/3/116176-16-5.bmp
#   inflating: train_set/3/116177-19-4.bmp
#   inflating: train_set/3/116177-19-5.bmp
#   inflating: train_set/3/116177-19-6.bmp
#   inflating: train_set/3/116178-20-4.bmp
#   inflating: train_set/3/126116-10-3.bmp
#   inflating: train_set/3/126117-15-6.bmp
#   inflating: train_set/3/126117-17-3.bmp
#   inflating: train_set/3/126119-28-4.bmp
#   inflating: train_set/3/126125-18-4.bmp
#   inflating: train_set/3/126140-9-4.bmp
#   inflating: train_set/3/126142-4-4.bmp
#   inflating: train_set/3/126143-5-3.bmp
#   inflating: train_set/3/126147-10-4.bmp
#   inflating: train_set/3/126147-7-4.bmp
#   inflating: train_set/3/126147-9-4.bmp
#   inflating: train_set/3/126147-9-5.bmp
#   inflating: train_set/3/126151-7-3.bmp
#   inflating: train_set/3/126152-14-4.bmp
#   inflating: train_set/3/126152-14-6.bmp
#   inflating: train_set/3/126152-16-4.bmp
#   inflating: train_set/3/126152-16-6.bmp
#   inflating: train_set/3/126152-21-4.bmp
#   inflating: train_set/3/126152-21-6.bmp
#   inflating: train_set/3/126152-23-5.bmp
#   inflating: train_set/3/126153-28-5.bmp
#   inflating: train_set/3/126154-11-6.bmp
#   inflating: train_set/3/136151-13-5.bmp
#   inflating: train_set/3/136151-16-5.bmp
#   inflating: train_set/3/136151-5-3.bmp
#   inflating: train_set/3/136151-8-4.bmp
#   inflating: train_set/3/136151-8-5.bmp
#   inflating: train_set/3/136151-8-6.bmp
#   inflating: train_set/3/136151-9-5.bmp
#   inflating: train_set/3/136151-9-6.bmp
#   inflating: train_set/3/136153-27-3.bmp
#   inflating: train_set/3/136153-29-4.bmp
#   inflating: train_set/3/136154-2-6.bmp
#   inflating: train_set/3/136155-1-4.bmp
#   inflating: train_set/3/136155-2-6.bmp
#   inflating: train_set/3/136156-10-5.bmp
#   inflating: train_set/3/136156-10-6.bmp
#   inflating: train_set/3/136156-11-6.bmp
#   inflating: train_set/3/136156-4-3.bmp
#   inflating: train_set/3/136156-7-6.bmp
#   inflating: train_set/3/136156-8-5.bmp
#   inflating: train_set/3/136157-17-5.bmp
#   inflating: train_set/3/136157-21-4.bmp
#   inflating: train_set/3/136158-2-4.bmp
#   inflating: train_set/3/136158-25-5.bmp
#   inflating: train_set/3/136158-26-4.bmp
#   inflating: train_set/3/136159-12-5.bmp
#   inflating: train_set/3/136159-12-6.bmp
#   inflating: train_set/3/136159-8-5.bmp
#   inflating: train_set/3/136159-9-4.bmp
#   inflating: train_set/3/136160-4-6.bmp
#   inflating: train_set/3/136161-1-3.bmp
#   inflating: train_set/3/136161-1-6.bmp
#   inflating: train_set/3/136161-2-5.bmp
#   inflating: train_set/3/136161-2-6.bmp
#   inflating: train_set/3/136161-4-3.bmp
#   inflating: train_set/3/136161-4-5.bmp
#   inflating: train_set/3/136161-4-6.bmp
#   inflating: train_set/3/136163-5-5.bmp
#   inflating: train_set/3/136167-11-5.bmp
#   inflating: train_set/3/136167-17-3.bmp
#   inflating: train_set/3/146150-12-5.bmp
#   inflating: train_set/3/146151-19-6.bmp
#   inflating: train_set/3/37141-4-3.bmp
#   inflating: train_set/3/37141-6-6.bmp
#   inflating: train_set/3/37143-11-4.bmp
#   inflating: train_set/3/37143-11-6.bmp
#   inflating: train_set/3/37143-5-3.bmp
#   inflating: train_set/3/37144-12-3.bmp
#   inflating: train_set/3/37144-17-3.bmp
#   inflating: train_set/3/37145-26-4.bmp
#   inflating: train_set/3/37147-1-5.bmp
#   inflating: train_set/3/37150-21-5.bmp
#   inflating: train_set/3/37151-2-3.bmp
#   inflating: train_set/3/37151-2-4.bmp
#    creating: train_set/4/
#   inflating: train_set/4/.MATLABDriveTag
#   inflating: train_set/4/116151-14-6.bmp
#   inflating: train_set/4/116152-23-6.bmp
#   inflating: train_set/4/116152-24-4.bmp
#   inflating: train_set/4/116153-26-6.bmp
#   inflating: train_set/4/116153-31-4.bmp
#   inflating: train_set/4/116154-6-4.bmp
#   inflating: train_set/4/116154-9-5.bmp
#   inflating: train_set/4/116156-1-5.bmp
#   inflating: train_set/4/116158-4-4.bmp
#   inflating: train_set/4/116158-4-6.bmp
#   inflating: train_set/4/116170-16-4.bmp
#   inflating: train_set/4/116170-19-4.bmp
#   inflating: train_set/4/116170-19-6.bmp
#   inflating: train_set/4/116171-26-4.bmp
#   inflating: train_set/4/116171-26-6.bmp
#   inflating: train_set/4/116171-27-6.bmp
#   inflating: train_set/4/116171-28-5.bmp
#   inflating: train_set/4/116172-2-5.bmp
#   inflating: train_set/4/116173-4-4.bmp
#   inflating: train_set/4/116174-9-5.bmp
#   inflating: train_set/4/116175-4-5.bmp
#   inflating: train_set/4/116176-11-3.bmp
#   inflating: train_set/4/116176-6-3.bmp
#   inflating: train_set/4/116176-6-4.bmp
#   inflating: train_set/4/116176-6-5.bmp
#   inflating: train_set/4/116176-9-3.bmp
#   inflating: train_set/4/126116-10-5.bmp
#   inflating: train_set/4/126116-7-6.bmp
#   inflating: train_set/4/126117-15-5.bmp
#   inflating: train_set/4/126118-21-6.bmp
#   inflating: train_set/4/126118-22-6.bmp
#   inflating: train_set/4/126142-3-6.bmp
#   inflating: train_set/4/126147-6-6.bmp
#   inflating: train_set/4/126147-9-3.bmp
#   inflating: train_set/4/126147-9-6.bmp
#   inflating: train_set/4/126151-10-6.bmp
#   inflating: train_set/4/126151-8-6.bmp
#   inflating: train_set/4/126152-15-3.bmp
#   inflating: train_set/4/126152-20-3.bmp
#   inflating: train_set/4/126152-20-4.bmp
#   inflating: train_set/4/126153-25-5.bmp
#   inflating: train_set/4/126153-3-4.bmp
#   inflating: train_set/4/126154-15-3.bmp
#   inflating: train_set/4/126154-8-5.bmp
#   inflating: train_set/4/136151-13-3.bmp
#   inflating: train_set/4/136153-30-3.bmp
#   inflating: train_set/4/136155-2-5.bmp
#   inflating: train_set/4/136156-12-3.bmp
#   inflating: train_set/4/136156-12-6.bmp
#   inflating: train_set/4/136156-5-3.bmp
#   inflating: train_set/4/136157-18-4.bmp
#   inflating: train_set/4/136157-19-3.bmp
#   inflating: train_set/4/136157-19-4.bmp
#   inflating: train_set/4/136160-4-4.bmp
#   inflating: train_set/4/136167-14-6.bmp
#   inflating: train_set/4/136167-18-4.bmp
#   inflating: train_set/4/136167-19-3.bmp
#   inflating: train_set/4/136167-19-6.bmp
#   inflating: train_set/4/146150-12-6.bmp
#   inflating: train_set/4/146150-6-3.bmp
#   inflating: train_set/4/146150-6-4.bmp
#   inflating: train_set/4/146151-21-3.bmp
#   inflating: train_set/4/146151-23-6.bmp
#   inflating: train_set/4/146151-29-4.bmp
#   inflating: train_set/4/146152-32-3.bmp
#   inflating: train_set/4/146152-32-4.bmp
#   inflating: train_set/4/146153-4-3.bmp
#   inflating: train_set/4/146153-9-4.bmp
#   inflating: train_set/4/146154-11-4.bmp
#   inflating: train_set/4/146154-12-4.bmp
#   inflating: train_set/4/146154-12-6.bmp
#   inflating: train_set/4/146156-28-3.bmp
#   inflating: train_set/4/146156-28-4.bmp
#   inflating: train_set/4/196143-7-3.bmp
#   inflating: train_set/4/196146-6-4.bmp
#   inflating: train_set/4/196146-7-6.bmp
#   inflating: train_set/4/196147-10-4.bmp
#   inflating: train_set/4/196147-13-3.bmp
#   inflating: train_set/4/196147-13-6.bmp
#   inflating: train_set/4/196148-14-5.bmp
#   inflating: train_set/4/196148-18-3.bmp
#   inflating: train_set/4/196148-21-4.bmp
#   inflating: train_set/4/196148-23-4.bmp
#   inflating: train_set/4/206150-4-4.bmp
#   inflating: train_set/4/206151-10-3.bmp
#   inflating: train_set/4/206151-10-4.bmp
#   inflating: train_set/4/206151-10-6.bmp
#   inflating: train_set/4/206152-11-3.bmp
#   inflating: train_set/4/206153-2-5.bmp
#   inflating: train_set/4/206153-5-5.bmp
#   inflating: train_set/4/206154-11-3.bmp
#   inflating: train_set/4/206155-1-4.bmp
#   inflating: train_set/4/206155-2-5.bmp
#   inflating: train_set/4/206155-2-6.bmp
#   inflating: train_set/4/206155-6-3.bmp
#   inflating: train_set/4/206157-4-4.bmp
#   inflating: train_set/4/206158-5-4.bmp
#   inflating: train_set/4/37141-3-4.bmp
#   inflating: train_set/4/37144-15-3.bmp
#   inflating: train_set/4/37145-24-6.bmp
#    creating: train_set/5/
#   inflating: train_set/5/.MATLABDriveTag
#   inflating: train_set/5/116151-12-3.bmp
#   inflating: train_set/5/116151-12-6.bmp
#   inflating: train_set/5/116151-13-4.bmp
#   inflating: train_set/5/116151-14-4.bmp
#   inflating: train_set/5/116151-15-3.bmp
#   inflating: train_set/5/116151-9-5.bmp
#   inflating: train_set/5/116152-19-6.bmp
#   inflating: train_set/5/116152-20-3.bmp
#   inflating: train_set/5/116152-21-4.bmp
#   inflating: train_set/5/116152-23-3.bmp
#   inflating: train_set/5/116152-23-5.bmp
#   inflating: train_set/5/116152-25-6.bmp
#   inflating: train_set/5/116155-10-3.bmp
#   inflating: train_set/5/116156-2-3.bmp
#   inflating: train_set/5/116158-5-5.bmp
#   inflating: train_set/5/116158-6-6.bmp
#   inflating: train_set/5/116170-12-4.bmp
#   inflating: train_set/5/116171-28-3.bmp
#   inflating: train_set/5/116172-2-3.bmp
#   inflating: train_set/5/116173-3-3.bmp
#   inflating: train_set/5/116175-4-3.bmp
#   inflating: train_set/5/116176-12-5.bmp
#   inflating: train_set/5/116176-15-5.bmp
#   inflating: train_set/5/116176-8-6.bmp
#   inflating: train_set/5/116176-9-4.bmp
#   inflating: train_set/5/116176-9-6.bmp
#   inflating: train_set/5/126116-4-5.bmp
#   inflating: train_set/5/126116-5-5.bmp
#   inflating: train_set/5/126117-11-3.bmp
#   inflating: train_set/5/126117-11-6.bmp
#   inflating: train_set/5/126117-16-5.bmp
#   inflating: train_set/5/126118-23-3.bmp
#   inflating: train_set/5/126119-25-4.bmp
#   inflating: train_set/5/126119-27-4.bmp
#   inflating: train_set/5/126119-27-5.bmp
#   inflating: train_set/5/126140-8-4.bmp
#   inflating: train_set/5/126142-3-3.bmp
#   inflating: train_set/5/126147-10-6.bmp
#   inflating: train_set/5/126152-19-3.bmp
#   inflating: train_set/5/126152-22-3.bmp
#   inflating: train_set/5/126152-23-3.bmp
#   inflating: train_set/5/126152-23-6.bmp
#   inflating: train_set/5/126153-2-5.bmp
#   inflating: train_set/5/126154-12-5.bmp
#   inflating: train_set/5/126154-15-6.bmp
#   inflating: train_set/5/136151-12-4.bmp
#   inflating: train_set/5/136151-13-6.bmp
#   inflating: train_set/5/136151-15-3.bmp
#   inflating: train_set/5/136151-18-3.bmp
#   inflating: train_set/5/136151-18-5.bmp
#   inflating: train_set/5/136151-19-4.bmp
#   inflating: train_set/5/136152-21-5.bmp
#   inflating: train_set/5/136152-21-6.bmp
#   inflating: train_set/5/136153-25-6.bmp
#   inflating: train_set/5/136153-31-5.bmp
#   inflating: train_set/5/136154-3-5.bmp
#   inflating: train_set/5/136155-1-6.bmp
#   inflating: train_set/5/136156-5-4.bmp
#   inflating: train_set/5/136156-6-6.bmp
#   inflating: train_set/5/136156-9-5.bmp
#   inflating: train_set/5/136157-15-3.bmp
#   inflating: train_set/5/136157-18-6.bmp
#   inflating: train_set/5/136157-20-3.bmp
#   inflating: train_set/5/136157-20-4.bmp
#   inflating: train_set/5/136157-21-5.bmp
#   inflating: train_set/5/136157-21-6.bmp
#   inflating: train_set/5/136157-22-3.bmp
#   inflating: train_set/5/136158-3-3.bmp
#   inflating: train_set/5/136158-3-6.bmp
#   inflating: train_set/5/136158-6-3.bmp
#   inflating: train_set/5/136158-6-6.bmp
#   inflating: train_set/5/136159-9-5.bmp
#   inflating: train_set/5/136166-9-6.bmp
#   inflating: train_set/5/136167-11-3.bmp
#   inflating: train_set/5/136167-14-3.bmp
#   inflating: train_set/5/136167-20-4.bmp
#   inflating: train_set/5/146150-10-6.bmp
#   inflating: train_set/5/146150-16-4.bmp
#   inflating: train_set/5/146150-7-6.bmp
#   inflating: train_set/5/146151-29-3.bmp
#   inflating: train_set/5/146152-32-5.bmp
#   inflating: train_set/5/146152-38-3.bmp
#   inflating: train_set/5/37139-7-6.bmp
#   inflating: train_set/5/37141-5-5.bmp
#   inflating: train_set/5/37141-6-5.bmp
#   inflating: train_set/5/37142-2-4.bmp
#   inflating: train_set/5/37143-10-5.bmp
#   inflating: train_set/5/37143-11-5.bmp
#   inflating: train_set/5/37143-4-3.bmp
#   inflating: train_set/5/37143-4-4.bmp
#   inflating: train_set/5/37143-4-6.bmp
#   inflating: train_set/5/37143-6-6.bmp
#   inflating: train_set/5/37143-9-4.bmp
#   inflating: train_set/5/37144-13-3.bmp
#   inflating: train_set/5/37144-16-5.bmp
#   inflating: train_set/5/37145-23-5.bmp
#   inflating: train_set/5/37145-25-3.bmp
#   inflating: train_set/5/37147-1-6.bmp
#   inflating: train_set/5/37148-5-3.bmp
#   inflating: train_set/5/37151-2-5.bmp
#    creating: train_set/6/
#   inflating: train_set/6/.MATLABDriveTag
#   inflating: train_set/6/116150-7-4.bmp
#   inflating: train_set/6/116151-11-5.bmp
#   inflating: train_set/6/116151-9-4.bmp
#   inflating: train_set/6/116152-19-3.bmp
#   inflating: train_set/6/116152-25-5.bmp
#   inflating: train_set/6/116153-26-4.bmp
#   inflating: train_set/6/116153-28-5.bmp
#   inflating: train_set/6/116154-3-5.bmp
#   inflating: train_set/6/116155-10-4.bmp
#   inflating: train_set/6/116155-10-6.bmp
#   inflating: train_set/6/116156-2-4.bmp
#   inflating: train_set/6/116156-2-6.bmp
#   inflating: train_set/6/116158-3-4.bmp
#   inflating: train_set/6/116158-3-6.bmp
#   inflating: train_set/6/116158-4-3.bmp
#   inflating: train_set/6/116158-6-3.bmp
#   inflating: train_set/6/116170-11-5.bmp
#   inflating: train_set/6/116170-12-3.bmp
#   inflating: train_set/6/116170-17-3.bmp
#   inflating: train_set/6/116170-18-4.bmp
#   inflating: train_set/6/116171-23-5.bmp
#   inflating: train_set/6/116171-23-6.bmp
#   inflating: train_set/6/116171-24-5.bmp
#   inflating: train_set/6/116171-24-6.bmp
#   inflating: train_set/6/116174-7-4.bmp
#   inflating: train_set/6/116176-10-6.bmp
#   inflating: train_set/6/116176-11-5.bmp
#   inflating: train_set/6/116176-13-3.bmp
#   inflating: train_set/6/116176-16-4.bmp
#   inflating: train_set/6/116176-5-3.bmp
#   inflating: train_set/6/116176-5-4.bmp
#   inflating: train_set/6/116176-5-5.bmp
#   inflating: train_set/6/116176-9-5.bmp
#   inflating: train_set/6/126115-1-3.bmp
#   inflating: train_set/6/126115-2-5.bmp
#   inflating: train_set/6/126115-3-6.bmp
#   inflating: train_set/6/126116-10-6.bmp
#   inflating: train_set/6/126116-5-6.bmp
#   inflating: train_set/6/126116-6-4.bmp
#   inflating: train_set/6/126117-13-5.bmp
#   inflating: train_set/6/126117-17-6.bmp
#   inflating: train_set/6/126118-22-4.bmp
#   inflating: train_set/6/126119-26-4.bmp
#   inflating: train_set/6/126119-28-3.bmp
#   inflating: train_set/6/126125-18-3.bmp
#   inflating: train_set/6/126140-8-3.bmp
#   inflating: train_set/6/126140-8-5.bmp
#   inflating: train_set/6/126140-9-3.bmp
#   inflating: train_set/6/126142-4-3.bmp
#   inflating: train_set/6/126147-7-3.bmp
#   inflating: train_set/6/126147-7-5.bmp
#   inflating: train_set/6/126147-7-6.bmp
#   inflating: train_set/6/126147-8-3.bmp
#   inflating: train_set/6/126151-10-3.bmp
#   inflating: train_set/6/126151-10-4.bmp
#   inflating: train_set/6/126151-8-5.bmp
#   inflating: train_set/6/126151-9-3.bmp
#   inflating: train_set/6/126152-14-3.bmp
#   inflating: train_set/6/126152-15-5.bmp
#   inflating: train_set/6/126152-15-6.bmp
#   inflating: train_set/6/126152-19-6.bmp
#   inflating: train_set/6/126153-2-4.bmp
#   inflating: train_set/6/126153-24-6.bmp
#   inflating: train_set/6/126153-3-6.bmp
#   inflating: train_set/6/136150-3-4.bmp
#   inflating: train_set/6/136151-16-4.bmp
#   inflating: train_set/6/136151-5-4.bmp
#   inflating: train_set/6/136151-7-4.bmp
#   inflating: train_set/6/136153-23-3.bmp
#   inflating: train_set/6/136153-25-4.bmp
#   inflating: train_set/6/136153-26-3.bmp
#   inflating: train_set/6/136153-26-4.bmp
#   inflating: train_set/6/136156-6-5.bmp
#   inflating: train_set/6/136157-17-4.bmp
#   inflating: train_set/6/136158-2-3.bmp
#   inflating: train_set/6/136158-2-5.bmp
#   inflating: train_set/6/136158-2-6.bmp
#   inflating: train_set/6/136158-26-3.bmp
#   inflating: train_set/6/136158-26-5.bmp
#   inflating: train_set/6/136158-26-6.bmp
#   inflating: train_set/6/136158-3-4.bmp
#   inflating: train_set/6/136158-5-4.bmp
#   inflating: train_set/6/136158-6-4.bmp
#   inflating: train_set/6/136159-8-4.bmp
#   inflating: train_set/6/136165-7-5.bmp
#   inflating: train_set/6/136167-15-5.bmp
#   inflating: train_set/6/136167-20-5.bmp
#   inflating: train_set/6/146150-12-4.bmp
#   inflating: train_set/6/146150-9-4.bmp
#   inflating: train_set/6/146151-19-4.bmp
#   inflating: train_set/6/146151-20-4.bmp
#   inflating: train_set/6/146152-35-5.bmp
#   inflating: train_set/6/37138-11-6.bmp
#   inflating: train_set/6/37138-4-6.bmp
#   inflating: train_set/6/37141-4-5.bmp
#   inflating: train_set/6/37143-11-3.bmp
#   inflating: train_set/6/37145-24-4.bmp
#   inflating: train_set/6/37147-2-5.bmp
#   inflating: train_set/6/37147-2-6.bmp
#   inflating: train_set/6/37148-4-3.bmp
#    creating: train_set/7/
#   inflating: train_set/7/.MATLABDriveTag
#   inflating: train_set/7/116151-10-6.bmp
#   inflating: train_set/7/116151-11-3.bmp
#   inflating: train_set/7/116151-11-4.bmp
#   inflating: train_set/7/116151-12-4.bmp
#   inflating: train_set/7/116151-12-5.bmp
#   inflating: train_set/7/116152-25-3.bmp
#   inflating: train_set/7/116154-9-3.bmp
#   inflating: train_set/7/116155-11-5.bmp
#   inflating: train_set/7/116156-1-3.bmp
#   inflating: train_set/7/116156-3-5.bmp
#   inflating: train_set/7/116170-14-3.bmp
#   inflating: train_set/7/116170-14-5.bmp
#   inflating: train_set/7/116170-17-4.bmp
#   inflating: train_set/7/116170-18-5.bmp
#   inflating: train_set/7/116171-28-4.bmp
#   inflating: train_set/7/116172-2-4.bmp
#   inflating: train_set/7/116174-7-5.bmp
#   inflating: train_set/7/116174-8-5.bmp
#   inflating: train_set/7/116176-10-4.bmp
#   inflating: train_set/7/116176-10-5.bmp
#   inflating: train_set/7/116176-13-5.bmp
#   inflating: train_set/7/116176-15-3.bmp
#   inflating: train_set/7/116176-15-4.bmp
#   inflating: train_set/7/116178-20-3.bmp
#   inflating: train_set/7/116178-20-6.bmp
#   inflating: train_set/7/126115-3-3.bmp
#   inflating: train_set/7/126116-5-3.bmp
#   inflating: train_set/7/126116-6-3.bmp
#   inflating: train_set/7/126116-6-5.bmp
#   inflating: train_set/7/126116-6-6.bmp
#   inflating: train_set/7/126116-8-5.bmp
#   inflating: train_set/7/126117-16-3.bmp
#   inflating: train_set/7/126117-17-5.bmp
#   inflating: train_set/7/126117-18-3.bmp
#   inflating: train_set/7/126118-21-4.bmp
#   inflating: train_set/7/126118-22-3.bmp
#   inflating: train_set/7/126118-23-5.bmp
#   inflating: train_set/7/126119-26-5.bmp
#   inflating: train_set/7/126125-19-5.bmp
#   inflating: train_set/7/126140-6-5.bmp
#   inflating: train_set/7/126143-5-5.bmp
#   inflating: train_set/7/126147-8-4.bmp
#   inflating: train_set/7/126147-8-5.bmp
#   inflating: train_set/7/126147-8-6.bmp
#   inflating: train_set/7/126152-17-5.bmp
#   inflating: train_set/7/126152-18-6.bmp
#   inflating: train_set/7/126152-22-4.bmp
#   inflating: train_set/7/126153-2-3.bmp
#   inflating: train_set/7/126153-28-3.bmp
#   inflating: train_set/7/126153-28-4.bmp
#   inflating: train_set/7/126154-10-3.bmp
#   inflating: train_set/7/126154-11-5.bmp
#   inflating: train_set/7/126154-12-4.bmp
#   inflating: train_set/7/126154-6-5.bmp
#   inflating: train_set/7/126154-9-5.bmp
#   inflating: train_set/7/136150-3-6.bmp
#   inflating: train_set/7/136151-16-3.bmp
#   inflating: train_set/7/136151-17-4.bmp
#   inflating: train_set/7/136151-5-5.bmp
#   inflating: train_set/7/136151-7-6.bmp
#   inflating: train_set/7/136153-23-5.bmp
#   inflating: train_set/7/136153-27-5.bmp
#   inflating: train_set/7/136153-29-6.bmp
#   inflating: train_set/7/136156-12-4.bmp
#   inflating: train_set/7/136156-4-6.bmp
#   inflating: train_set/7/136156-5-5.bmp
#   inflating: train_set/7/136156-7-3.bmp
#   inflating: train_set/7/136156-7-4.bmp
#   inflating: train_set/7/136156-7-5.bmp
#   inflating: train_set/7/136156-9-3.bmp
#   inflating: train_set/7/136157-15-4.bmp
#   inflating: train_set/7/136157-16-5.bmp
#   inflating: train_set/7/136157-16-6.bmp
#   inflating: train_set/7/136157-17-6.bmp
#   inflating: train_set/7/136157-19-5.bmp
#   inflating: train_set/7/136157-22-5.bmp
#   inflating: train_set/7/136159-7-5.bmp
#   inflating: train_set/7/136161-2-3.bmp
#   inflating: train_set/7/37138-11-5.bmp
#   inflating: train_set/7/37138-2-3.bmp
#   inflating: train_set/7/37138-2-5.bmp
#   inflating: train_set/7/37138-3-3.bmp
#   inflating: train_set/7/37138-4-3.bmp
#   inflating: train_set/7/37141-1-4.bmp
#   inflating: train_set/7/37141-1-5.bmp
#   inflating: train_set/7/37141-2-5.bmp
#   inflating: train_set/7/37141-3-6.bmp
#   inflating: train_set/7/37141-4-6.bmp
#   inflating: train_set/7/37141-6-4.bmp
#   inflating: train_set/7/37142-1-3.bmp
#   inflating: train_set/7/37142-3-5.bmp
#   inflating: train_set/7/37143-10-6.bmp
#   inflating: train_set/7/37144-17-4.bmp
#   inflating: train_set/7/37144-18-5.bmp
#   inflating: train_set/7/37145-19-4.bmp
#   inflating: train_set/7/37145-20-5.bmp
#   inflating: train_set/7/37145-20-6.bmp
#   inflating: train_set/7/37145-24-5.bmp
#   inflating: train_set/7/37145-25-5.bmp
#   inflating: train_set/7/37148-5-4.bmp
#    creating: train_set/8/
#   inflating: train_set/8/.MATLABDriveTag
#   inflating: train_set/8/116150-7-5.bmp
#   inflating: train_set/8/116151-13-5.bmp
#   inflating: train_set/8/116151-17-6.bmp
#   inflating: train_set/8/116152-21-3.bmp
#   inflating: train_set/8/116152-24-3.bmp
#   inflating: train_set/8/116152-24-5.bmp
#   inflating: train_set/8/116152-24-6.bmp
#   inflating: train_set/8/116152-25-4.bmp
#   inflating: train_set/8/116155-10-5.bmp
#   inflating: train_set/8/116156-2-5.bmp
#   inflating: train_set/8/116158-3-3.bmp
#   inflating: train_set/8/116158-3-5.bmp
#   inflating: train_set/8/116158-5-2.bmp
#   inflating: train_set/8/116170-12-5.bmp
#   inflating: train_set/8/116170-18-6.bmp
#   inflating: train_set/8/116171-23-4.bmp
#   inflating: train_set/8/116171-24-4.bmp
#   inflating: train_set/8/116173-3-5.bmp
#   inflating: train_set/8/116173-4-5.bmp
#   inflating: train_set/8/116175-2-4.bmp
#   inflating: train_set/8/116175-2-6.bmp
#   inflating: train_set/8/116178-20-5.bmp
#   inflating: train_set/8/126115-1-5.bmp
#   inflating: train_set/8/126115-3-5.bmp
#   inflating: train_set/8/126116-10-4.bmp
#   inflating: train_set/8/126116-4-3.bmp
#   inflating: train_set/8/126116-7-3.bmp
#   inflating: train_set/8/126116-7-5.bmp
#   inflating: train_set/8/126117-11-5.bmp
#   inflating: train_set/8/126119-26-3.bmp
#   inflating: train_set/8/126125-18-5.bmp
#   inflating: train_set/8/126140-9-5.bmp
#   inflating: train_set/8/126142-3-5.bmp
#   inflating: train_set/8/126147-6-5.bmp
#   inflating: train_set/8/126151-7-6.bmp
#   inflating: train_set/8/126151-8-4.bmp
#   inflating: train_set/8/126152-17-3.bmp
#   inflating: train_set/8/126152-17-6.bmp
#   inflating: train_set/8/126153-1-6.bmp
#   inflating: train_set/8/126153-2-6.bmp
#   inflating: train_set/8/126153-24-3.bmp
#   inflating: train_set/8/126153-29-6.bmp
#   inflating: train_set/8/126154-11-3.bmp
#   inflating: train_set/8/126154-13-3.bmp
#   inflating: train_set/8/126154-13-5.bmp
#   inflating: train_set/8/126154-13-6.bmp
#   inflating: train_set/8/126154-5-5.bmp
#   inflating: train_set/8/136150-28-4.bmp
#   inflating: train_set/8/136150-28-6.bmp
#   inflating: train_set/8/136151-12-3.bmp
#   inflating: train_set/8/136151-15-5.bmp
#   inflating: train_set/8/136151-17-6.bmp
#   inflating: train_set/8/136151-18-6.bmp
#   inflating: train_set/8/136151-9-4.bmp
#   inflating: train_set/8/136153-22-3.bmp
#   inflating: train_set/8/136154-2-4.bmp
#   inflating: train_set/8/136156-11-5.bmp
#   inflating: train_set/8/136156-9-4.bmp
#   inflating: train_set/8/136157-17-3.bmp
#   inflating: train_set/8/136157-20-5.bmp
#   inflating: train_set/8/136157-20-6.bmp
#   inflating: train_set/8/136158-25-4.bmp
#   inflating: train_set/8/136161-4-4.bmp
#   inflating: train_set/8/136163-2-4.bmp
#   inflating: train_set/8/136163-2-5.bmp
#   inflating: train_set/8/136163-2-6.bmp
#   inflating: train_set/8/136165-7-3.bmp
#   inflating: train_set/8/136165-7-4.bmp
#   inflating: train_set/8/136165-7-6.bmp
#   inflating: train_set/8/136166-9-3.bmp
#   inflating: train_set/8/136166-9-4.bmp
#   inflating: train_set/8/136167-12-4.bmp
#   inflating: train_set/8/136167-12-6.bmp
#   inflating: train_set/8/136167-13-6.bmp
#   inflating: train_set/8/136167-19-5.bmp
#   inflating: train_set/8/136167-20-6.bmp
#   inflating: train_set/8/146150-15-5.bmp
#   inflating: train_set/8/146151-21-6.bmp
#   inflating: train_set/8/146152-38-6.bmp
#   inflating: train_set/8/146152-39-4.bmp
#   inflating: train_set/8/146153-1-6.bmp
#   inflating: train_set/8/146153-2-4.bmp
#   inflating: train_set/8/146154-12-3.bmp
#   inflating: train_set/8/146154-13-5.bmp
#   inflating: train_set/8/146154-14-5.bmp
#   inflating: train_set/8/37138-1-5.bmp
#   inflating: train_set/8/37138-6-3.bmp
#   inflating: train_set/8/37139-7-4.bmp
#   inflating: train_set/8/37141-2-3.bmp
#   inflating: train_set/8/37141-5-3.bmp
#   inflating: train_set/8/37141-5-6.bmp
#   inflating: train_set/8/37141-6-3.bmp
#   inflating: train_set/8/37143-4-5.bmp
#   inflating: train_set/8/37143-5-6.bmp
#   inflating: train_set/8/37143-6-4.bmp
#   inflating: train_set/8/37144-12-6.bmp
#   inflating: train_set/8/37144-17-5.bmp
#   inflating: train_set/8/37145-22-6.bmp
#   inflating: train_set/8/37147-2-4.bmp
#   inflating: train_set/8/37148-4-6.bmp
#    creating: train_set/9/
#   inflating: train_set/9/.MATLABDriveTag
#   inflating: train_set/9/116150-7-3.bmp
#   inflating: train_set/9/116151-13-6.bmp
#   inflating: train_set/9/116151-17-3.bmp
#   inflating: train_set/9/116151-9-3.bmp
#   inflating: train_set/9/116152-19-5.bmp
#   inflating: train_set/9/116152-20-6.bmp
#   inflating: train_set/9/116154-7-3.bmp
#   inflating: train_set/9/116154-7-5.bmp
#   inflating: train_set/9/116170-14-4.bmp
#   inflating: train_set/9/116170-16-5.bmp
#   inflating: train_set/9/116171-26-3.bmp
#   inflating: train_set/9/116171-26-5.bmp
#   inflating: train_set/9/116171-27-3.bmp
#   inflating: train_set/9/116175-4-6.bmp
#   inflating: train_set/9/116176-11-4.bmp
#   inflating: train_set/9/116176-11-6.bmp
#   inflating: train_set/9/116176-12-6.bmp
#   inflating: train_set/9/116176-14-4.bmp
#   inflating: train_set/9/116176-5-6.bmp
#   inflating: train_set/9/116176-8-5.bmp
#   inflating: train_set/9/126115-2-4.bmp
#   inflating: train_set/9/126115-2-6.bmp
#   inflating: train_set/9/126117-15-4.bmp
#   inflating: train_set/9/126117-18-5.bmp
#   inflating: train_set/9/126118-20-3.bmp
#   inflating: train_set/9/126118-21-5.bmp
#   inflating: train_set/9/126118-23-6.bmp
#   inflating: train_set/9/126119-25-6.bmp
#   inflating: train_set/9/126119-28-5.bmp
#   inflating: train_set/9/126142-3-4.bmp
#   inflating: train_set/9/126142-4-5.bmp
#   inflating: train_set/9/126143-5-6.bmp
#   inflating: train_set/9/126152-14-5.bmp
#   inflating: train_set/9/126152-18-3.bmp
#   inflating: train_set/9/126152-18-5.bmp
#   inflating: train_set/9/126152-22-6.bmp
#   inflating: train_set/9/126153-24-5.bmp
#   inflating: train_set/9/126153-26-4.bmp
#   inflating: train_set/9/126153-26-5.bmp
#   inflating: train_set/9/126154-10-4.bmp
#   inflating: train_set/9/126154-11-4.bmp
#   inflating: train_set/9/126154-13-4.bmp
#   inflating: train_set/9/126154-5-4.bmp
#   inflating: train_set/9/126154-6-6.bmp
#   inflating: train_set/9/126154-8-4.bmp
#   inflating: train_set/9/126154-8-6.bmp
#   inflating: train_set/9/126154-9-4.bmp
#   inflating: train_set/9/126154-9-6.bmp
#   inflating: train_set/9/136150-3-3.bmp
#   inflating: train_set/9/136151-5-6.bmp
#   inflating: train_set/9/136153-22-5.bmp
#   inflating: train_set/9/136153-26-5.bmp
#   inflating: train_set/9/136153-29-5.bmp
#   inflating: train_set/9/136156-10-4.bmp
#   inflating: train_set/9/136156-12-5.bmp
#   inflating: train_set/9/136156-13-3.bmp
#   inflating: train_set/9/136156-13-5.bmp
#   inflating: train_set/9/136156-13-6.bmp
#   inflating: train_set/9/136156-6-4.bmp
#   inflating: train_set/9/136156-8-6.bmp
#   inflating: train_set/9/136165-6-3.bmp
#   inflating: train_set/9/136165-6-4.bmp
#   inflating: train_set/9/136165-6-6.bmp
#   inflating: train_set/9/136166-9-5.bmp
#   inflating: train_set/9/136167-12-5.bmp
#   inflating: train_set/9/136167-13-4.bmp
#   inflating: train_set/9/146150-6-5.bmp
#   inflating: train_set/9/146150-6-6.bmp
#   inflating: train_set/9/146152-35-3.bmp
#   inflating: train_set/9/146153-5-5.bmp
#   inflating: train_set/9/146154-16-4.bmp
#   inflating: train_set/9/146156-27-6.bmp
#   inflating: train_set/9/196142-1-6.bmp
#   inflating: train_set/9/196142-3-4.bmp
#   inflating: train_set/9/196142-5-5.bmp
#   inflating: train_set/9/196146-2-6.bmp
#   inflating: train_set/9/196146-3-6.bmp
#   inflating: train_set/9/196146-5-3.bmp
#   inflating: train_set/9/196147-12-6.bmp
#   inflating: train_set/9/196147-13-5.bmp
#   inflating: train_set/9/196148-14-4.bmp
#   inflating: train_set/9/37138-1-4.bmp
#   inflating: train_set/9/37138-5-5.bmp
#   inflating: train_set/9/37138-5-6.bmp
#   inflating: train_set/9/37138-6-5.bmp
#   inflating: train_set/9/37139-1-4.bmp
#   inflating: train_set/9/37139-1-5.bmp
#   inflating: train_set/9/37139-1-6.bmp
#   inflating: train_set/9/37139-7-3.bmp
#   inflating: train_set/9/37139-7-5.bmp
#   inflating: train_set/9/37141-5-4.bmp
#   inflating: train_set/9/37142-3-6.bmp
#   inflating: train_set/9/37143-9-6.bmp
#   inflating: train_set/9/37144-12-4.bmp
#   inflating: train_set/9/37145-22-3.bmp
#   inflating: train_set/9/37145-23-4.bmp
#   inflating: train_set/9/37145-23-6.bmp
#   inflating: train_set/9/37147-1-4.bmp
#   inflating: train_set/9/37147-2-3.bmp
#   inflating: train_set/9/37148-4-4.bmp

# %%
# Configurando o Ambiente
import glob

TRAINING_FILES = 600 # Quantidade de arquivos para treinamento

# Lista com o caminho das pastas
circlePath = ["./formas_out/1_circle/"]
squarePath = ["./formas_out/2_square/"]
starPath = ["./formas_out/3_star/"]
trianglePath = ["./formas_out/4_triangle/"]

# %%
# Função para listar os arquivos e separar os pirmeiros TRAINING_FILES como treino
def spread_test(folder_path):
  files = glob.glob(f"{folder_path}*.png")
  return (files[:TRAINING_FILES], files[TRAINING_FILES:])

# Função para listar os arquivos e separar os pirmeiros TRAINING_FILES como treino
def spread_training_test(folder_path: list[str]):
  trainign_files, test_files = spread_test(folder_path[-1])
  # for path in folder_path[:-1]:
  #   trainign_files.extend(glob.glob(f"{path}*.png"))
  return (trainign_files, test_files)

# Separando arquivo de treino e de teste
circleTraingFilesList, circleTestFilesList = spread_training_test(circlePath)
squareTraingFilesList, squareTestFilesList = spread_training_test(squarePath)
starTraingFilesList, starTestFilesList = spread_training_test(starPath)
triangleTraingFilesList, triangleTestFilesList = spread_training_test(trianglePath)

# %%
from PIL import Image
import numpy as np

# Função para abrir os arquivos como double e normalizar a imagem preto e branca
def open_files(file_list, threshold=0.5):
    np_array_list = []
    for file in file_list:
        img = Image.open(file).convert("L")
        img_array = np.array(img, dtype=np.float64) / 255.0
        # Binariza usando threshold fixo
        binary = (img_array > threshold).astype(np.float64)
        np_array_list.append(binary)
    return np.array(np_array_list)

# Abrindo arquivos de treino
X_train_circle = open_files(circleTraingFilesList)
X_train_square = open_files(squareTraingFilesList)
X_train_star = open_files(starTraingFilesList)
X_train_triangle = open_files(triangleTraingFilesList)

# Abrindo arquivos de teste
X_test_circle = open_files(circleTestFilesList)
X_test_square = open_files(squareTestFilesList)
X_test_star = open_files(starTestFilesList)
X_test_triangle = open_files(triangleTestFilesList)

# %%
# Juntar todos os treinos
X_train = np.concatenate([X_train_circle, X_train_square, X_train_star, X_train_triangle], axis=0)
X_test  = np.concatenate([X_test_circle, X_test_square, X_test_star, X_test_triangle], axis=0)

# Criar os rótulos (0=circle, 1=square, 2=star, 3=triangle)
y_train = np.concatenate([
    np.zeros(len(X_train_circle)),
    np.ones(len(X_train_square)),
    2*np.ones(len(X_train_star)),
    3*np.ones(len(X_train_triangle))
], axis=0)

y_test = np.concatenate([
    np.zeros(len(X_test_circle)),
    np.ones(len(X_test_square)),
    2*np.ones(len(X_test_star)),
    3*np.ones(len(X_test_triangle))
], axis=0)

# %%
from skimage.measure import moments_hu, moments

# Função para calcular momentos de Hu de todas as imagens
def extract_hu_features(images):
    features = []
    for img in images:
        m = moments(img)
        hu = moments_hu(m)
        # Normaliza os Momentos de HU
        hu = [-np.sign(h) * np.log10(abs(h)) if h != 0 else 0 for h in hu]
        features.append(hu)
    return np.array(features)

# Extrair features
X_train_features = extract_hu_features(X_train)
X_test_features  = extract_hu_features(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Cria o classificador
knn = KNeighborsClassifier(n_neighbors=1)
# Resultados:
# Padrão (distância euclidiana), 1 vizinho me permitiu 0.764375 e 3 0.7775
# Manhattan, 1 vizinho me deu 76125 e 3 0.775

# Treina
knn.fit(X_train_features, y_train)

# Prediz
y_pred = knn.predict(X_test_features)

# Avalia
acc = accuracy_score(y_test, y_pred)
print("Acurácia do k-NN:", acc)
# Out:
# Acurácia do k-NN: 0.678125

# %%
# Funções de Hu Moments para calcular por zonas

# Função para dividir a imagem em zonas
def split_image(img, nx, ny):
    h, w = img.shape
    zones = []
    h_step = h // ny
    w_step = w // nx
    for i in range(ny):
        for j in range(nx):
            zone = img[i*h_step:(i+1)*h_step, j*w_step:(j+1)*w_step]
            zones.append(zone)
    return zones

# Função para calcular os momentos de hu em cada zona
def hu_features_zones(img, nx=2, ny=2):
    zones = split_image(img, nx, ny)
    features = []
    for z in zones:
        m = moments(z)
        hu = moments_hu(m)
        hu = [-np.sign(h) * np.log10(abs(h)) if h != 0 else 0 for h in hu]
        features.extend(hu)
    return np.array(features)

# Função para calcular os momentos de hu par auma lista de imagens
def extract_features_all(images, nx=2, ny=2):
    all_features = []
    for img in images:
        feat = hu_features_zones(img, nx, ny)
        all_features.append(feat)
    return np.array(all_features)

# %%
# Classificação com k-NN usando diferentes parâmetros
# (número de zonas horizontais e verticais) para os momentos invariantes de HU

best_acc = 0
best_params = (1,1)

for nx in range(1, 5):
    for ny in range(1, 5):
        # Extrai features
        X_train_f = extract_features_all(X_train, nx, ny)
        X_test_f  = extract_features_all(X_test, nx, ny)

        # Treina k-NN
        knn = KNeighborsClassifier(n_neighbors=3)
        knn.fit(X_train_f, y_train)
        y_pred = knn.predict(X_test_f)

        # Avalia
        acc = accuracy_score(y_test, y_pred)
        print(f"Acurácia {nx}x{ny} zonas: {acc:.4f}")

        # Guarda melhor resultado
        if acc > best_acc:
            best_acc = acc
            best_params = (nx, ny)

print(f"\nMelhor acurácia: {best_acc:.4f} com {best_params[0]}x{best_params[1]} zonas")
# Out:
# Acurácia 1x1 zonas: 0.6963
# Acurácia 1x2 zonas: 0.8462
# Acurácia 1x3 zonas: 0.9156
# Acurácia 1x4 zonas: 0.9044
# Acurácia 2x1 zonas: 0.8069
# Acurácia 2x2 zonas: 0.8825
# Acurácia 2x3 zonas: 0.9594
# Acurácia 2x4 zonas: 0.9425
# Acurácia 3x1 zonas: 0.9225
# Acurácia 3x2 zonas: 0.9650
# Acurácia 3x3 zonas: 0.8769
# Acurácia 3x4 zonas: 0.9344
# Acurácia 4x1 zonas: 0.8988
# Acurácia 4x2 zonas: 0.9431
# Acurácia 4x3 zonas: 0.9350
# Acurácia 4x4 zonas: 0.8512
#
# Melhor acurácia: 0.9650 com 3x2 zonas

# %%
TRAINING_FILES = 60 # Quantidade de arquivos para treinamento

# Lista com o caminho das pastas
zeroPath  = ["./train_set/0/"]
onePath   = ["./train_set/1/"]
twoPath   = ["./train_set/2/"]
threePath = ["./train_set/3/"]
fourPath  = ["./train_set/4/"]
fivePath  = ["./train_set/5/"]
sixPath   = ["./train_set/6/"]
sevenPath = ["./train_set/7/"]
eightPath = ["./train_set/8/"]
ninePath  = ["./train_set/9/"]

# Função para listar os arquivos e separar os pirmeiros TRAINING_FILES como treino
def spread_test(folder_path):
  files = glob.glob(f"{folder_path}*.bmp")
  return (files[:TRAINING_FILES], files[TRAINING_FILES:])

# Função para listar os arquivos e separar os pirmeiros TRAINING_FILES como treino
def spread_training_test(folder_path: list[str]):
  trainign_files, test_files = spread_test(folder_path[-1])
  # for path in folder_path[:-1]:
  #   trainign_files.extend(glob.glob(f"{path}*.png"))
  return (trainign_files, test_files)


# Separando arquivo de treino e de teste
zeroTraingFilesList, zeroTestFilesList = spread_training_test(zeroPath)
oneTraingFilesList, oneTestFilesList = spread_training_test(onePath)
twoTraingFilesList, twoTestFilesList = spread_training_test(twoPath)
threeTraingFilesList, threeTestFilesList = spread_training_test(threePath)
fourTraingFilesList, fourTestFilesList = spread_training_test(fourPath)
fiveTraingFilesList, fiveTestFilesList = spread_training_test(fivePath)
sixTraingFilesList, sixTestFilesList = spread_training_test(sixPath)
sevenTraingFilesList, sevenTestFilesList = spread_training_test(sevenPath)
eightTraingFilesList, eightTestFilesList = spread_training_test(eightPath)
nineTraingFilesList, nineTestFilesList = spread_training_test(ninePath)


def get_max_size(all_file_lists):
    max_w, max_h = 0, 0
    for file_list in all_file_lists:
        for file in file_list:
            img = Image.open(file).convert("L")
            w, h = img.size
            max_w = max(max_w, w)
            max_h = max(max_h, h)
    return max_w, max_h

all_train_lists = [
    zeroTraingFilesList, oneTraingFilesList, twoTraingFilesList,
    threeTraingFilesList, fourTraingFilesList, fiveTraingFilesList,
    sixTraingFilesList, sevenTraingFilesList, eightTraingFilesList,
    nineTraingFilesList
]

max_size = get_max_size(all_train_lists)


def open_files(file_list, max_size, threshold=0.5):
    max_w, max_h = max_size
    np_array_list = []
    for file in file_list:
        img = Image.open(file).convert("L")
        w, h = img.size

        # Criar imagem branca com tamanho maximo
        new_img = Image.new("L", (max_w, max_h), color=255)
        # Coloca a imagem no canto superior esquerdo
        x_offset = (max_w - w) // 2
        y_offset = (max_h - h) // 2
        new_img.paste(img, (x_offset, y_offset))

        img_array = np.array(new_img, dtype=np.float64) / 255.0
        binary = (img_array > threshold).astype(np.float64)
        np_array_list.append(binary)
    return np.array(np_array_list)


# Abrindo arquivos de treino
X_train_zero = open_files(zeroTraingFilesList, max_size)
X_train_one = open_files(oneTraingFilesList, max_size)
X_train_two = open_files(twoTraingFilesList, max_size)
X_train_three = open_files(threeTraingFilesList, max_size)
X_train_four = open_files(fourTraingFilesList, max_size)
X_train_five = open_files(fiveTraingFilesList, max_size)
X_train_six = open_files(sixTraingFilesList, max_size)
X_train_seven = open_files(sevenTraingFilesList, max_size)
X_train_eight = open_files(eightTraingFilesList, max_size)
X_train_nine = open_files(nineTraingFilesList, max_size)


# Abrindo arquivos de teste
X_test_zero = open_files(zeroTestFilesList, max_size)
X_test_one = open_files(oneTestFilesList, max_size)
X_test_two = open_files(twoTestFilesList, max_size)
X_test_three = open_files(threeTestFilesList, max_size)
X_test_four = open_files(fourTestFilesList, max_size)
X_test_five = open_files(fiveTestFilesList, max_size)
X_test_six = open_files(sixTestFilesList, max_size)
X_test_seven = open_files(sevenTestFilesList, max_size)
X_test_eight = open_files(eightTestFilesList, max_size)
X_test_nine = open_files(nineTestFilesList, max_size)


# Juntar todos os treinos
X_train = np.concatenate([
    X_train_zero, X_train_one, X_train_two, X_train_three,
    X_train_four, X_train_five, X_train_six, X_train_seven,
    X_train_eight, X_train_nine
], axis=0)
X_test  = np.concatenate([
    X_test_zero, X_test_one, X_test_two, X_test_three,
    X_test_four, X_test_five, X_test_six, X_test_seven,
    X_test_eight, X_test_nine
], axis=0)


# Criar os rotulos (0 a 9)
y_train = np.concatenate([
    np.full(len(X_train_zero), 0),
    np.full(len(X_train_one), 1),
    np.full(len(X_train_two), 2),
    np.full(len(X_train_three), 3),
    np.full(len(X_train_four), 4),
    np.full(len(X_train_five), 5),
    np.full(len(X_train_six), 6),
    np.full(len(X_train_seven), 7),
    np.full(len(X_train_eight), 8),
    np.full(len(X_train_nine), 9)
], axis=0)

y_test = np.concatenate([
    np.full(len(X_test_zero), 0),
    np.full(len(X_test_one), 1),
    np.full(len(X_test_two), 2),
    np.full(len(X_test_three), 3),
    np.full(len(X_test_four), 4),
    np.full(len(X_test_five), 5),
    np.full(len(X_test_six), 6),
    np.full(len(X_test_seven), 7),
    np.full(len(X_test_eight), 8),
    np.full(len(X_test_nine), 9)
], axis=0)


# Classificação com k-NN usando diferentes parâmetros
# (número de zonas horizontais e verticais) para os momentos invariantes de HU

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

best_acc = 0
best_params = (1,1)

for nx in range(1, 5):
    for ny in range(1, 5):
        # Extrai features
        X_train_f = extract_features_all(X_train, nx, ny)
        X_test_f  = extract_features_all(X_test, nx, ny)

        # Normaliza usando Z-score
        scaler = StandardScaler()
        X_train_f_scaled = scaler.fit_transform(X_train_f)
        X_test_f_scaled  = scaler.transform(X_test_f)

        # Treina k-NN
        knn = KNeighborsClassifier(n_neighbors=5)
        knn.fit(X_train_f_scaled, y_train)
        y_pred = knn.predict(X_test_f_scaled)

        # Avalia
        acc = accuracy_score(y_test, y_pred)
        print(f"Acurácia {nx}x{ny} zonas: {acc:.4f}")

        # Guarda melhor resultado
        if acc > best_acc:
            best_acc = acc
            best_params = (nx, ny)

print(f"\nMelhor acurácia: {best_acc:.4f} com {best_params[0]}x{best_params[1]} zonas")
# Out:
# Acurácia 1x1 zonas: 0.4650
# Acurácia 1x2 zonas: 0.6875
# Acurácia 1x3 zonas: 0.7075
# Acurácia 1x4 zonas: 0.7625
# Acurácia 2x1 zonas: 0.5525
# Acurácia 2x2 zonas: 0.8225
# Acurácia 2x3 zonas: 0.8725
# Acurácia 2x4 zonas: 0.8925
# Acurácia 3x1 zonas: 0.5725
# Acurácia 3x2 zonas: 0.8050
# Acurácia 3x3 zonas: 0.8650
# Acurácia 3x4 zonas: 0.8475
# Acurácia 4x1 zonas: 0.6075
# Acurácia 4x2 zonas: 0.8825
# Acurácia 4x3 zonas: 0.7850
# Acurácia 4x4 zonas: 0.8725
#
# Melhor acurácia: 0.8925 com 2x4 zonas
